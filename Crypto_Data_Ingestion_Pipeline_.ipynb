# %% [markdown]
# <a href="https://colab.research.google.com/github/MaitreePimple/ETL-Projects-/blob/main/Crypto_Data_Ingestion_Pipeline_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

url = "https://api.coingecko.com/api/v3/coins/markets"

params = {
    "vs_currency" : "usd",
    "order" : "market_cap_desc",
    "per_page":10,
    "page":1
}

response = requests.get(url,params=params)
data = response.json()

df = pd.DataFrame(data)

df = df[["id","symbol","current_price","market_cap","total_volume"]]

df.to_csv("crypto_data.csv",index=False)

print("csv file created ")
# Out:
# csv file created

# %%
import pandas as pd


df = pd.read_csv("crypto_data.csv")
df.head()
# Out:
#             id symbol  current_price     market_cap  total_volume
# 0      bitcoin    btc    81717.00000  1636165541350   45475975907
# 1     ethereum    eth     2359.21000   284634457721   20880268946
# 2       tether   usdt        0.99988   189555207587   81735644675
# 3       ripple    xrp        1.43000    88423627032    2660723036
# 4  binancecoin    bnb      648.46000    87372072516    1491636963
